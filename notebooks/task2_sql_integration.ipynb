# %%
import os
import sys

print(os.getcwd())
# Out:
# c:\Users\purua\projects\apexplanet-data-analytics\notebooks

# %%
import sys
import os

sys.path.append(os.path.abspath("../scripts"))

from db_utils import get_connection

# %%
import os

print(os.path.abspath("../scripts"))
# Out:
# c:\Users\purua\projects\apexplanet-data-analytics\scripts

# %%
from db_utils import get_connection

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/customer_churn.db")

query = """
SELECT Contract,
AVG(Monthly_Charges) AS AvgCharge
FROM customer_churn
GROUP BY Contract;
"""

df = pd.read_sql(query, conn)

print(df)

conn.close()
# Out:
#          Contract  AvgCharge
# 0  Month-to-month  66.398490
# 1        One year  65.048608
# 2        Two year  60.770413

# %%
from db_utils import get_connection

# %%
from db_utils import get_connection
import pandas as pd

conn = get_connection()

query = """
SELECT Contract,
AVG(Monthly_Charges) AS AvgCharge
FROM customer_churn
GROUP BY Contract;
"""

df = pd.read_sql(query, conn)

print(df)

conn.close()
# Out:
#          Contract  AvgCharge
# 0  Month-to-month  66.398490
# 1        One year  65.048608
# 2        Two year  60.770413
